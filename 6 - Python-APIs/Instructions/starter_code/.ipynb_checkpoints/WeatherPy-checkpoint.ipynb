# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
# query = city
query_url = f"{base_url}&appid={api_key}&q="

# Lists
city_name = []
lat = []
temp = []
humidity = []
cloudiness = []
windspeed = []

# query_url
count = 1
for city in cities:
    try:
        response = requests.get(query_url + city)
        city_data = response.json()
        city_name.append(city_data['name'])
        lat.append(city_data['coord']['lat'])
        temp.append(city_data['main']['temp'])
        humidity.append(city_data['main']['humidity'])
        cloudiness.append(city_data['clouds']['all'])
        windspeed.append(city_data['wind']['speed'])
        print(f"Processing Record of Set {count} | {city}")
    except:
        print('City not found. Skipping...')
    count += 1

# for city in cities:
#     response = requests.get(query_url + city)
#     city_data = response.json()
#     print(city_data['name'])
# Out:
# Processing Record of Set 1 | innisfail
# Processing Record of Set 2 | rikitea
# Processing Record of Set 3 | qaanaaq
# City not found. Skipping...
# Processing Record of Set 5 | botwood
# Processing Record of Set 6 | ushuaia
# City not found. Skipping...
# Processing Record of Set 8 | punta arenas
# City not found. Skipping...
# Processing Record of Set 10 | grand gaube
# Processing Record of Set 11 | trakai
# Processing Record of Set 12 | japura
# Processing Record of Set 13 | beringovskiy
# Processing Record of Set 14 | filadelfia
# Processing Record of Set 15 | maxixe
# Processing Record of Set 16 | bethel
# Processing Record of Set 17 | bay city
# City not found. Skipping...
# Processing Record of Set 19 | severodvinsk
# Processing Record of Set 20 | omboue
# City not found. Skipping...
# Processing Record of Set 22 | chuy
# Processing Record of Set 23 | puerto ayora
# Processing Record of Set 24 | butaritari
# Processing Record of Set 25 | atuona
# Processing Record of Set 26 | mount gambier
# Processing Record of Set 27 | busselton
# Processing Record of Set 28 | port hardy
# Processing Record of Set 29 | chokurdakh
# Processing Record of Set 30 | pangnirtung
# Processing Record of Set 31 | bograd
# Processing Record of Set 32 | ust-omchug
# Processing Record of Set 33 | kaitangata
# Processing Record of Set 34 | jamestown
# Processing Record of Set 35 | hermanus
# Processing Record of Set 36 | veliki preslav
# City not found. Skipping...
# Processing Record of Set 38 | preobrazheniye
# Processing Record of Set 39 | sangar
# Processing Record of Set 40 | puerto rondon
# Processing Record of Set 41 | khatanga
# Processing Record of Set 42 | avarua
# Processing Record of Set 43 | albany
# Processing Record of Set 44 | mataura
# Processing Record of Set 45 | linxia
# Processing Record of Set 46 | honiara
# City not found. Skipping...
# Processing Record of Set 48 | trois-rivieres
# Processing Record of Set 49 | hobart
# Processing Record of Set 50 | machalpur
# Processing Record of Set 51 | port pirie
# Processing Record of Set 52 | tasiilaq
# Processing Record of Set 53 | bredasdorp
# Processing Record of Set 54 | faanui
# Processing Record of Set 55 | vaini
# Processing Record of Set 56 | la ronge
# Processing Record of Set 57 | kenai
# Processing Record of Set 58 | new norfolk
# Processing Record of Set 59 | zhigansk
# City not found. Skipping...
# Processing Record of Set 61 | port alfred
# Processing Record of Set 62 | marquelia
# Processing Record of Set 63 | saint-philippe
# Processing Record of Set 64 | banjar
# Processing Record of Set 65 | sur
# Processing Record of Set 66 | telciu
# Processing Record of Set 67 | oytal
# Processing Record of Set 68 | knin
# Processing Record of Set 69 | road town
# Processing Record of Set 70 | coquimbo
# Processing Record of Set 71 | nhulunbuy
# Processing Record of Set 72 | sao filipe
# Processing Record of Set 73 | salalah
# Processing Record of Set 74 | kalmunai
# Processing Record of Set 75 | rio gallegos
# Processing Record of Set 76 | lingao
# Processing Record of Set 77 | east london
# City not found. Skipping...
# Processing Record of Set 79 | shenjiamen
# Processing Record of Set 80 | batemans bay
# Processing Record of Set 81 | castro
# Processing Record of Set 82 | challapata
# Processing Record of Set 83 | barabai
# Processing Record of Set 84 | kapaa
# City not found. Skipping...
# Processing Record of Set 86 | yellowknife
# Processing Record of Set 87 | cape town
# City not found. Skipping...
# Processing Record of Set 89 | cabo san lucas
# Processing Record of Set 90 | tiksi
# Processing Record of Set 91 | jinji
# Processing Record of Set 92 | touros
# Processing Record of Set 93 | mindelo
# Processing Record of Set 94 | guozhen
# Processing Record of Set 95 | bluff
# Processing Record of Set 96 | san patricio
# Processing Record of Set 97 | saldanha
# Processing Record of Set 98 | arraial do cabo
# Processing Record of Set 99 | fukue
# Processing Record of Set 100 | lompoc
# Processing Record of Set 101 | hilo
# Processing Record of Set 102 | sao joao batista
# Processing Record of Set 103 | guiglo
# Processing Record of Set 104 | cuamba
# Processing Record of Set 105 | geraldton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record of Set 108 | mariental
# Processing Record of Set 109 | cidreira
# Processing Record of Set 110 | kijang
# Processing Record of Set 111 | klaksvik
# Processing Record of Set 112 | paamiut
# Processing Record of Set 113 | amga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record of Set 116 | port elizabeth
# Processing Record of Set 117 | codrington
# City not found. Skipping...
# Processing Record of Set 119 | katsuura
# Processing Record of Set 120 | madras
# City not found. Skipping...
# Processing Record of Set 122 | college
# Processing Record of Set 123 | bambanglipuro
# City not found. Skipping...
# Processing Record of Set 125 | chute-aux-outardes
# Processing Record of Set 126 | thompson
# Processing Record of Set 127 | bilma
# Processing Record of Set 128 | souillac
# Processing Record of Set 129 | prince rupert
# Processing Record of Set 130 | balikpapan
# Processing Record of Set 131 | norman wells
# Processing Record of Set 132 | saint george
# Processing Record of Set 133 | galle
# Processing Record of Set 134 | itoman
# Processing Record of Set 135 | meadville
# City not found. Skipping...
# Processing Record of Set 137 | doha
# Processing Record of Set 138 | torbay
# Processing Record of Set 139 | kuchurhan
# Processing Record of Set 140 | aricestii-rahtivani
# Processing Record of Set 141 | meulaboh
# Processing Record of Set 142 | meadow lake
# Processing Record of Set 143 | takoradi
# Processing Record of Set 144 | half moon bay
# Processing Record of Set 145 | saskylakh
# Processing Record of Set 146 | leningradskiy
# Processing Record of Set 147 | alakurtti
# Processing Record of Set 148 | patterson
# Processing Record of Set 149 | saint anthony
# Processing Record of Set 150 | sambava
# Processing Record of Set 151 | srednekolymsk
# Processing Record of Set 152 | laguna
# Processing Record of Set 153 | waddan
# Processing Record of Set 154 | payo
# City not found. Skipping...
# Processing Record of Set 156 | vallenar
# City not found. Skipping...
# Processing Record of Set 158 | tahoua
# Processing Record of Set 159 | krasnoyarskiy
# Processing Record of Set 160 | palmer
# Processing Record of Set 161 | dikson
# Processing Record of Set 162 | beyneu
# Processing Record of Set 163 | suez
# Processing Record of Set 164 | bay roberts
# Processing Record of Set 165 | mahebourg
# Processing Record of Set 166 | bathsheba
# Processing Record of Set 167 | okhotsk
# Processing Record of Set 168 | buala
# City not found. Skipping...
# Processing Record of Set 170 | lavrentiya
# Processing Record of Set 171 | suzun
# Processing Record of Set 172 | seriate
# Processing Record of Set 173 | camocim
# Processing Record of Set 174 | margate
# Processing Record of Set 175 | karasjok
# Processing Record of Set 176 | bandarbeyla
# Processing Record of Set 177 | nikolskoye
# Processing Record of Set 178 | krasnovishersk
# City not found. Skipping...
# Processing Record of Set 180 | henties bay
# Processing Record of Set 181 | oksfjord
# Processing Record of Set 182 | ostrovnoy
# Processing Record of Set 183 | jaisalmer
# Processing Record of Set 184 | manuk mangkaw
# Processing Record of Set 185 | aklavik
# Processing Record of Set 186 | petilia policastro
# Processing Record of Set 187 | narsaq
# Processing Record of Set 188 | raudeberg
# City not found. Skipping...
# Processing Record of Set 190 | sao felix do xingu
# Processing Record of Set 191 | husavik
# Processing Record of Set 192 | ovre ardal
# Processing Record of Set 193 | berlevag
# Processing Record of Set 194 | broken hill
# Processing Record of Set 195 | sao joao da barra
# Processing Record of Set 196 | naze
# Processing Record of Set 197 | san martin
# Processing Record of Set 198 | tuatapere
# Processing Record of Set 199 | nhlangano
# Processing Record of Set 200 | luderitz
# Processing Record of Set 201 | timra
# Processing Record of Set 202 | curaca
# City not found. Skipping...
# Processing Record of Set 204 | goderich
# Processing Record of Set 205 | indian head
# Processing Record of Set 206 | asosa
# Processing Record of Set 207 | kruisfontein
# Processing Record of Set 208 | atasu
# Processing Record of Set 209 | clyde river
# Processing Record of Set 210 | ancud
# Processing Record of Set 211 | lata
# Processing Record of Set 212 | atambua
# Processing Record of Set 213 | vardo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record of Set 216 | santa vitoria do palmar
# Processing Record of Set 217 | bakchar
# Processing Record of Set 218 | hay river
# City not found. Skipping...
# Processing Record of Set 220 | comodoro rivadavia
# Processing Record of Set 221 | zeya
# Processing Record of Set 222 | tilichiki
# City not found. Skipping...
# Processing Record of Set 224 | westport
# Processing Record of Set 225 | riohacha
# Processing Record of Set 226 | longonjo
# Processing Record of Set 227 | puerto del rosario
# Processing Record of Set 228 | bingol
# Processing Record of Set 229 | yaqui
# Processing Record of Set 230 | kodiak
# Processing Record of Set 231 | lorengau
# Processing Record of Set 232 | furmanov
# Processing Record of Set 233 | bambous virieux
# Processing Record of Set 234 | lebu
# Processing Record of Set 235 | beloha
# Processing Record of Set 236 | pevek
# Processing Record of Set 237 | guatire
# Processing Record of Set 238 | chara
# Processing Record of Set 239 | luanda
# Processing Record of Set 240 | provideniya
# Processing Record of Set 241 | yulara
# Processing Record of Set 242 | north platte
# Processing Record of Set 243 | port lincoln
# Processing Record of Set 244 | havoysund
# Processing Record of Set 245 | sitka
# Processing Record of Set 246 | hithadhoo
# Processing Record of Set 247 | bhikangaon
# Processing Record of Set 248 | sorland
# Processing Record of Set 249 | boende
# Processing Record of Set 250 | high level
# Processing Record of Set 251 | carnarvon
# Processing Record of Set 252 | abadan
# Processing Record of Set 253 | cruzilia
# City not found. Skipping...
# Processing Record of Set 255 | san vicente
# Processing Record of Set 256 | constitucion
# Processing Record of Set 257 | mudgee
# Processing Record of Set 258 | bukan
# City not found. Skipping...
# Processing Record of Set 260 | hasaki
# City not found. Skipping...
# Processing Record of Set 262 | tura
# City not found. Skipping...
# Processing Record of Set 264 | najran
# Processing Record of Set 265 | griffith
# Processing Record of Set 266 | anadyr
# Processing Record of Set 267 | aanekoski
# Processing Record of Set 268 | tommot
# Processing Record of Set 269 | vanimo
# Processing Record of Set 270 | corinth
# Processing Record of Set 271 | waipawa
# Processing Record of Set 272 | serik
# Processing Record of Set 273 | accra
# Processing Record of Set 274 | dzerzhinsk
# Processing Record of Set 275 | udachnyy
# Processing Record of Set 276 | hambantota
# Processing Record of Set 277 | cherskiy
# Processing Record of Set 278 | teahupoo
# Processing Record of Set 279 | broome
# Processing Record of Set 280 | kirakira
# Processing Record of Set 281 | brownsville
# Processing Record of Set 282 | ouallam
# City not found. Skipping...
# Processing Record of Set 284 | smithers
# Processing Record of Set 285 | necochea
# Processing Record of Set 286 | haines junction
# Processing Record of Set 287 | ustye
# Processing Record of Set 288 | solnechnyy
# Processing Record of Set 289 | belmonte
# Processing Record of Set 290 | esperance
# Processing Record of Set 291 | caravelas
# Processing Record of Set 292 | havelock
# Processing Record of Set 293 | tuktoyaktuk
# Processing Record of Set 294 | victoria
# Processing Record of Set 295 | oranjemund
# Processing Record of Set 296 | kyzyl-suu
# Processing Record of Set 297 | verkh-usugli
# City not found. Skipping...
# Processing Record of Set 299 | awbari
# Processing Record of Set 300 | severo-kurilsk
# Processing Record of Set 301 | narasannapeta
# Processing Record of Set 302 | ratnagiri
# City not found. Skipping...
# Processing Record of Set 304 | ponta do sol
# Processing Record of Set 305 | cabedelo
# Processing Record of Set 306 | alta floresta
# Processing Record of Set 307 | camargo
# Processing Record of Set 308 | nome
# Processing Record of Set 309 | penzance
# Processing Record of Set 310 | san isidro
# Processing Record of Set 311 | newton
# Processing Record of Set 312 | alofi
# Processing Record of Set 313 | salina cruz
# Processing Record of Set 314 | bima
# Processing Record of Set 315 | mersing
# Processing Record of Set 316 | khasan
# Processing Record of Set 317 | cururupu
# Processing Record of Set 318 | fairbanks
# Processing Record of Set 319 | isangel
# Processing Record of Set 320 | mitchell
# Processing Record of Set 321 | venancio aires
# Processing Record of Set 322 | bath
# Processing Record of Set 323 | miles city
# Processing Record of Set 324 | georgetown
# Processing Record of Set 325 | hienghene
# Processing Record of Set 326 | shitanjing
# Processing Record of Set 327 | chapais
# Processing Record of Set 328 | kavieng
# City not found. Skipping...
# Processing Record of Set 330 | talcahuano
# Processing Record of Set 331 | storm lake
# Processing Record of Set 332 | iqaluit
# City not found. Skipping...
# Processing Record of Set 334 | maun
# Processing Record of Set 335 | te anau
# Processing Record of Set 336 | trinidad
# Processing Record of Set 337 | mahibadhoo
# Processing Record of Set 338 | dmytrivka
# Processing Record of Set 339 | shingu
# Processing Record of Set 340 | yenagoa
# Processing Record of Set 341 | svetlogorsk
# Processing Record of Set 342 | leo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record of Set 346 | halifax
# Processing Record of Set 347 | grafton
# Processing Record of Set 348 | kadambur
# Processing Record of Set 349 | salihorsk
# Processing Record of Set 350 | kathmandu
# Processing Record of Set 351 | ballina
# Processing Record of Set 352 | alice springs
# City not found. Skipping...
# City not found. Skipping...
# Processing Record of Set 355 | biak
# Processing Record of Set 356 | kununurra
# Processing Record of Set 357 | tessalit
# Processing Record of Set 358 | longyearbyen
# City not found. Skipping...
# Processing Record of Set 360 | moshi
# City not found. Skipping...
# Processing Record of Set 362 | teguldet
# City not found. Skipping...
# Processing Record of Set 364 | salamiyah
# Processing Record of Set 365 | loa janan
# Processing Record of Set 366 | carbonia
# Processing Record of Set 367 | igarka
# Processing Record of Set 368 | kendari
# Processing Record of Set 369 | arlit
# Processing Record of Set 370 | sobolevo
# Processing Record of Set 371 | mayo
# Processing Record of Set 372 | coihaique
# Processing Record of Set 373 | deputatskiy
# Processing Record of Set 374 | grand-lahou
# Processing Record of Set 375 | bilibino
# Processing Record of Set 376 | marzuq
# Processing Record of Set 377 | scarborough
# Processing Record of Set 378 | palu
# Processing Record of Set 379 | ribeira grande
# Processing Record of Set 380 | mporokoso
# Processing Record of Set 381 | ipameri
# Processing Record of Set 382 | guerrero negro
# Processing Record of Set 383 | snezhnogorsk
# Processing Record of Set 384 | belyy yar
# Processing Record of Set 385 | carballo
# Processing Record of Set 386 | libreville
# Processing Record of Set 387 | novoagansk
# Processing Record of Set 388 | padang
# Processing Record of Set 389 | falakata
# Processing Record of Set 390 | gizo
# Processing Record of Set 391 | caldas novas
# Processing Record of Set 392 | flinders
# Processing Record of Set 393 | elk plain
# Processing Record of Set 394 | ahipara
# Processing Record of Set 395 | bokaro
# Processing Record of Set 396 | mombetsu
# Processing Record of Set 397 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record of Set 399 | sfantu gheorghe
# Processing Record of Set 400 | faya
# Processing Record of Set 401 | poum
# Processing Record of Set 402 | hofn
# Processing Record of Set 403 | lipari
# City not found. Skipping...
# Processing Record of Set 405 | kandrian
# Processing Record of Set 406 | champerico
# Processing Record of Set 407 | praia da vitoria
# Processing Record of Set 408 | sibay
# Processing Record of Set 409 | artyom
# Processing Record of Set 410 | wanning
# Processing Record of Set 411 | point fortin
# City not found. Skipping...
# Processing Record of Set 413 | mar del plata
# Processing Record of Set 414 | saurimo
# Processing Record of Set 415 | zheleznodorozhnyy
# Processing Record of Set 416 | upernavik
# Processing Record of Set 417 | aswan
# Processing Record of Set 418 | datia
# Processing Record of Set 419 | itarema
# City not found. Skipping...
# Processing Record of Set 421 | huarmey
# Processing Record of Set 422 | manono
# Processing Record of Set 423 | sabzevar
# Processing Record of Set 424 | ilebo
# Processing Record of Set 425 | whitehorse
# Processing Record of Set 426 | petropavlovka
# Processing Record of Set 427 | rundu
# Processing Record of Set 428 | lumeje
# Processing Record of Set 429 | gimli
# Processing Record of Set 430 | talnakh
# Processing Record of Set 431 | colares
# Processing Record of Set 432 | barcelona
# Processing Record of Set 433 | pisco
# Processing Record of Set 434 | khash
# Processing Record of Set 435 | ucluelet
# Processing Record of Set 436 | waitati
# Processing Record of Set 437 | totness
# Processing Record of Set 438 | kaili
# Processing Record of Set 439 | itaituba
# Processing Record of Set 440 | avera
# Processing Record of Set 441 | birnin kebbi
# Processing Record of Set 442 | fort-shevchenko
# Processing Record of Set 443 | winchester
# Processing Record of Set 444 | tazovskiy
# Processing Record of Set 445 | kangaatsiaq
# Processing Record of Set 446 | praya
# Processing Record of Set 447 | ilulissat
# Processing Record of Set 448 | kizema
# Processing Record of Set 449 | dekar
# Processing Record of Set 450 | tarko-sale
# Processing Record of Set 451 | hirara
# Processing Record of Set 452 | alamosa
# City not found. Skipping...
# Processing Record of Set 454 | sigli
# City not found. Skipping...
# Processing Record of Set 456 | aragarcas
# Processing Record of Set 457 | makakilo city
# Processing Record of Set 458 | jiwani
# Processing Record of Set 459 | lewisporte
# Processing Record of Set 460 | turukhansk
# Processing Record of Set 461 | vila franca do campo
# Processing Record of Set 462 | quang ngai
# Processing Record of Set 463 | clinton
# Processing Record of Set 464 | mildura
# Processing Record of Set 465 | bulgan
# Processing Record of Set 466 | almeria
# Processing Record of Set 467 | rio grande
# Processing Record of Set 468 | strezhevoy
# Processing Record of Set 469 | barrow
# Processing Record of Set 470 | curuguaty
# City not found. Skipping...
# Processing Record of Set 472 | elk city
# Processing Record of Set 473 | grindavik
# Processing Record of Set 474 | salisbury
# Processing Record of Set 475 | noumea
# Processing Record of Set 476 | aras
# Processing Record of Set 477 | severomuysk
# City not found. Skipping...
# Processing Record of Set 479 | yarada
# Processing Record of Set 480 | alyangula
# Processing Record of Set 481 | chimbote
# City not found. Skipping...
# Processing Record of Set 483 | darhan
# Processing Record of Set 484 | san buenaventura
# Processing Record of Set 485 | tiznit
# Processing Record of Set 486 | the pas
# Processing Record of Set 487 | lashio
# Processing Record of Set 488 | babu
# Processing Record of Set 489 | axim
# Processing Record of Set 490 | biryusinsk
# City not found. Skipping...
# Processing Record of Set 492 | nemuro
# Processing Record of Set 493 | abha
# City not found. Skipping...
# Processing Record of Set 495 | bakaly
# Processing Record of Set 496 | mehran
# Processing Record of Set 497 | cockburn town
# Processing Record of Set 498 | benguela
# Processing Record of Set 499 | kalamazoo
# Processing Record of Set 500 | los llanos de aridane
# City not found. Skipping...
# Processing Record of Set 502 | primorsk
# Processing Record of Set 503 | bahia de caraquez
# Processing Record of Set 504 | aykhal
# Processing Record of Set 505 | labuhan
# Processing Record of Set 506 | mina
# Processing Record of Set 507 | cedar city
# Processing Record of Set 508 | montepuez
# Processing Record of Set 509 | stabat
# Processing Record of Set 510 | port moresby
# Processing Record of Set 511 | altea
# Processing Record of Set 512 | lucea
# Processing Record of Set 513 | pushkino
# City not found. Skipping...
# Processing Record of Set 515 | mananjary
# City not found. Skipping...
# Processing Record of Set 517 | yerbogachen
# Processing Record of Set 518 | taoudenni
# Processing Record of Set 519 | constantine
# Processing Record of Set 520 | huitziltepec
# Processing Record of Set 521 | santo domingo
# Processing Record of Set 522 | sikonge
# Processing Record of Set 523 | pingliang
# Processing Record of Set 524 | mount isa
# Processing Record of Set 525 | pericos
# Processing Record of Set 526 | conceicao do araguaia
# Processing Record of Set 527 | nong khai
# Processing Record of Set 528 | vostok
# Processing Record of Set 529 | ondangwa
# Processing Record of Set 530 | egvekinot
# Processing Record of Set 531 | abu samrah
# Processing Record of Set 532 | vao
# Processing Record of Set 533 | puri
# Processing Record of Set 534 | key biscayne
# Processing Record of Set 535 | kavaratti
# City not found. Skipping...
# Processing Record of Set 537 | ahero
# Processing Record of Set 538 | portland
# Processing Record of Set 539 | beruwala
# Processing Record of Set 540 | emba
# Processing Record of Set 541 | kolpashevo
# Processing Record of Set 542 | tarakan
# City not found. Skipping...
# Processing Record of Set 544 | taltal
# Processing Record of Set 545 | santa cruz
# Processing Record of Set 546 | shimanovsk
# Processing Record of Set 547 | zhangjiakou
# Processing Record of Set 548 | lima
# Processing Record of Set 549 | sioux lookout
# Processing Record of Set 550 | namikupa
# Processing Record of Set 551 | vila
# Processing Record of Set 552 | kutum
# Processing Record of Set 553 | vilhena
# Processing Record of Set 554 | rehoboth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record of Set 557 | charlestown
# Processing Record of Set 558 | matara
# Processing Record of Set 559 | verkhovazhye
# Processing Record of Set 560 | black diamond
# Processing Record of Set 561 | ixtapa
# Processing Record of Set 562 | gombe
# Processing Record of Set 563 | vila velha
# Processing Record of Set 564 | fort nelson
# Processing Record of Set 565 | ambon
# Processing Record of Set 566 | hettstedt
# Processing Record of Set 567 | fez
# Processing Record of Set 568 | acari
# Processing Record of Set 569 | rusape
# Processing Record of Set 570 | plettenberg bay
# Processing Record of Set 571 | rock sound
# Processing Record of Set 572 | saint-denis
# Processing Record of Set 573 | zalantun
# Processing Record of Set 574 | dunedin
# Processing Record of Set 575 | kamina
# Processing Record of Set 576 | ceyhan
# Processing Record of Set 577 | emerald
# City not found. Skipping...
# Processing Record of Set 579 | hadejia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record of Set 582 | altamira
# Processing Record of Set 583 | camacha
# Processing Record of Set 584 | darab
# Processing Record of Set 585 | bichena
# Processing Record of Set 586 | bejar
# Processing Record of Set 587 | simao
# Processing Record of Set 588 | gat
# Processing Record of Set 589 | price
# Processing Record of Set 590 | olinala
# Processing Record of Set 591 | lagoa
# Processing Record of Set 592 | porto velho
# Processing Record of Set 593 | ketchikan
# Processing Record of Set 594 | kindia
# Processing Record of Set 595 | bara
# Processing Record of Set 596 | shimoda
# Processing Record of Set 597 | saint-pierre
# Processing Record of Set 598 | horizontina
# Processing Record of Set 599 | rantepao
# Processing Record of Set 600 | bonthe
# Processing Record of Set 601 | hualmay
# Processing Record of Set 602 | puerto escondido
# City not found. Skipping...
# Processing Record of Set 604 | gorodovikovsk
# Processing Record of Set 605 | san cristobal
# Processing Record of Set 606 | vuktyl
# Processing Record of Set 607 | maniitsoq
# Processing Record of Set 608 | tando jam
# Processing Record of Set 609 | talaya
# Processing Record of Set 610 | port hedland
# City not found. Skipping...
# Processing Record of Set 612 | mahanoro
# Processing Record of Set 613 | leshukonskoye
# Processing Record of Set 614 | andijon
# Processing Record of Set 615 | kahului
# Processing Record of Set 616 | nyurba
# Processing Record of Set 617 | launceston
# Processing Record of Set 618 | buraydah
# Processing Record of Set 619 | fortuna
# Processing Record of Set 620 | araouane
# City not found. Skipping...
# Processing Record of Set 622 | port augusta
# City not found. Skipping...
# Processing Record of Set 624 | nioro
# Processing Record of Set 625 | goma
# Processing Record of Set 626 | namibe
# Processing Record of Set 627 | olinda
# Processing Record of Set 628 | opunake
# Processing Record of Set 629 | fuyang
# City not found. Skipping...
# Processing Record of Set 631 | micheweni
# Processing Record of Set 632 | szalkszentmarton
# Processing Record of Set 633 | kyrylivka
# Processing Record of Set 634 | mayumba
# Processing Record of Set 635 | alekseyevsk
# Processing Record of Set 636 | tselina

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# city_data_df.to_csv("../Images/city_data.csv", index=False, header=True)

weather_dict = {
    "City": city_name,
    "Lat": lat,
    "Temp": temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": windspeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#         City    Lat     Temp  Humidity  Cloudiness  Wind Speed
# 0  Innisfail  52.02  264.580        92          40        3.56
# 1    Rikitea -23.12  296.933       100          92        5.91
# 2    Qaanaaq  77.48  250.383        95          36        0.96
# 3    Botwood  49.14  270.310        73          75        6.70
# 4    Ushuaia -54.81  286.150        54          75       10.30

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature (08/22/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/CityLatitudevsMaxTemperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (08/22/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/CityLatitudevsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/CityLatitudevsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/CityLatitudevsWindSpeed.png")
plt.show()
